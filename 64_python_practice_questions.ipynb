# %% [markdown]
# <a href="https://colab.research.google.com/github/Anannya-Vyas/PYTHON-CODE-/blob/main/64_python_practice_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LEARNING: repr() function

# %%
#Q1 print hello world
greeting = "hello world"
print(greeting)
# Out:
# hello world

# %%
greeting = "hello \n world"
print(greeting)
greeting
# print(repr(greeting))
# Out:
# hello
#  world
# 'hello \n world'

# %%
name1 ="raja"
name1
# print(repr(name1))
name2 ="rani"
# print(repr(name2))
name2
name3 ="maharaja"
# print(repr(name3))
name3
name4 ="maharani"
# print(repr(name4))
print("\n",name1,"\n", name2,"\n", name3,"\n", name4)
name4
# Out:
#  raja
#  rani
#  maharaja
#  maharani
# 'maharani'

# %%
#repr vs print
greeting =" hello\n world"
print (greeting )

print(repr(greeting))
greeting
# Out:
#  hello
#  world
# ' hello\n world'
# ' hello\n world'

# %% [markdown]
# repr vs print vs just simple typing the variable

# %%
greetings =" hello \n world"
# greetings
print(repr(greetings))
print(greetings)
#repr function
# Out:
# ' hello \n world'
#  hello
#  world

# %%
name1="raja"
name1

# print(repr(name1))
name2="rani"
name2
# print(repr(name2))
name3="rajkumari"
name1
# print(repr(name3))
# print("\n",name1,"\n", name2,"\n",name3)
# Out:
# 'raja'

# %% [markdown]
# . Write a Python program to do arithmetical operations addition and division.

# %%
a= int(input("enter the value of a "))
b= int(input("enter the value of b "))
addition = a+b
division = a/b
print(f"addition of no is: \n {addition}")
print(f"division of no is: \n {division}")
division
# Out:
# enter the value of a 345678
# enter the value of b 21345678
# addition of no is:
#  21691356
# division of no is:
#  0.016194285325582067
# 0.016194285325582067

# %% [markdown]
# 3. Write a Python program to find the area of a triangle
